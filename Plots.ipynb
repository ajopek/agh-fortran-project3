# %%
import pandas as pan
import matplotlib.pyplot as plot

# %%
# Load data
df = pan.read_table('result.data', sep=r"\s+", header=0)

# %%
df.loc[(df['func'] == "mm")].sort_values(by='n').groupby(['n', 'type']).agg({'time': 'mean'}).unstack().plot()

# %%
basic = df.loc[(df['type'] == "basic") & (df['func'] == "gauss")]
coarray = df.loc[(df['type'] == "coarray") & (df['func'] == "gauss")]

# %%
data16.sort_values(by='n').plot(figsize=(15, 10), x='n', y='error')
plot.show()
